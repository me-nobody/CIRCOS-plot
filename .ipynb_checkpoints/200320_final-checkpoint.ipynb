# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
os.getcwd()
# Out:
# 'C:\\Users\\anubr\\Documents\\Final_Analysis'

# %%
data=pd.read_csv('final_mutation.csv',encoding="utf-8")
pd.set_option('display.max_columns',None)
#pd.set_option('display.max_rows',None)

# %%
data[data.Gene_name=="mutK"]
# Out:
# Empty DataFrame
# ...

# %%
data.head()
# Out:
#        CHROM     POS REF                                                ALT  \
# 0  NC_3197.2  3197.2   A                             AGTAATTTTTAAAATAATAAGA
# 1  NC_3197.2  3197.2   A  ATGTAATTTTTAAAATAATAAGAGA,ATTAAAATAATAAGAGA,AA...
# 2  NC_3197.2  3197.2   C                                                  T
# 3  NC_3197.2  3197.2   A                                                  C
# 4  NC_3197.2  3197.2   A                                                  C
#
#       QUAL C_Cip A_cip cip_2B_S14 ntrc_gDNA_2 SCV_2 stm_1_S13 Change_type  \
# 0  214.458   ./.   ./.        ./.         1/1   ./.       ./.         NaN
# 1  214.458   1/1   2/2        3/3         ./.   2/2       ./.         NaN
# 2  221.999   1/1   1/1        1/1         ./.   ./.       ./.         SNP
# 3  221.999   1/1   1/1        1/1         ./.   ./.       ./.         SNP
# 4  221.999   1/1   1/1        1/1         ./.   ./.       ./.         SNP
#
# ...
